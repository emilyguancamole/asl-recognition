# %% [markdown]
# # Process Data using MMPose Pose Extraction
#
# This contains our code to extract the WLASL100 and process the videos into numpy arrays and glosses into integer labels using MMPose

# %%
# %pip install -U openmim
# %pip install mmengine
# %pip install "mmcv>=2.0.1"
# %pip install "mmpose>=1.1.0"
# Out:
# Requirement already satisfied: openmim in /opt/anaconda3/lib/python3.11/site-packages (0.3.9)
# Requirement already satisfied: Click in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (2.1.4)
# Requirement already satisfied: pip>=19.3 in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (23.3.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /opt/anaconda3/lib/python3.11/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in /opt/anaconda3/lib/python3.11/site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: ordered-set in /opt/anaconda3/lib/python3.11/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in /opt/anaconda3/lib/python3.11/site-packages (from opendatalab->openmim) (3.20.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from opendatalab->openmim) (4.65.0)
# Requirement already satisfied: openxlab in /opt/anaconda3/lib/python3.11/site-packages (from opendatalab->openmim) (0.0.38)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->openmim) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->openmim) (2024.2.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->openmim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: oss2~=2.17.0 in /opt/anaconda3/lib/python3.11/site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: setuptools~=60.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: crcmod>=1.7 in /opt/anaconda3/lib/python3.11/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /opt/anaconda3/lib/python3.11/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.15.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /opt/anaconda3/lib/python3.11/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.11/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Collecting mmengine
#   Downloading mmengine-0.10.4-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (3.8.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (6.0.1)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: yapf in /opt/anaconda3/lib/python3.11/site-packages (from mmengine) (0.40.2)
# Collecting opencv-python>=3 (from mmengine)
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->mmengine) (2.15.1)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmengine) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmengine) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Downloading mmengine-0.10.4-py3-none-any.whl (451 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 9.1 MB/s eta 0:00:00ta 0:00:01
# Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict, opencv-python, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.4 opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.
# Collecting mmcv>=2.0.1
#   Downloading mmcv-2.1.0.tar.gz (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.4/471.4 kB 6.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: addict in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (0.10.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (1.26.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (23.2)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (10.2.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (6.0.1)
# Requirement already satisfied: yapf in /opt/anaconda3/lib/python3.11/site-packages (from mmcv>=2.0.1) (0.40.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from mmengine>=0.3.0->mmcv>=2.0.1) (3.8.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.11/site-packages (from mmengine>=0.3.0->mmcv>=2.0.1) (13.4.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.11/site-packages (from mmengine>=0.3.0->mmcv>=2.0.1) (2.4.0)
# Requirement already satisfied: opencv-python>=3 in /opt/anaconda3/lib/python3.11/site-packages (from mmengine>=0.3.0->mmcv>=2.0.1) (4.9.0.80)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmcv>=2.0.1) (7.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmcv>=2.0.1) (3.10.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from yapf->mmcv>=2.0.1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.1) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.1) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.1) (1.16.0)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp311-cp311-macosx_11_0_arm64.whl size=1167915 sha256=a8303e2697602b7f40037efb65fdb1396e4212fb0b473c4d053479bf2d392b1b
#   Stored in directory: /Users/renabi/Library/Caches/pip/wheels/57/22/96/9bcbfeaa838c1b705a4b2ac082539767fbcc79fa07ec01abcd
# Successfully built mmcv
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting mmpose>=1.1.0
#   Downloading mmpose-1.3.1-py2.py3-none-any.whl.metadata (29 kB)
# Collecting chumpy (from mmpose>=1.1.0)
#   Downloading chumpy-0.70.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting json-tricks (from mmpose>=1.1.0)
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (3.8.0)
# Requirement already satisfied: munkres in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (1.1.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (1.26.4)
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (4.9.0.80)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (10.2.0)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from mmpose>=1.1.0) (1.12.0)
# Collecting torchvision (from mmpose>=1.1.0)
#   Downloading torchvision-0.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting xtcocotools>=1.12 (from mmpose>=1.1.0)
#   Downloading xtcocotools-1.14.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (364 bytes)
# Requirement already satisfied: setuptools>=18.0 in /opt/anaconda3/lib/python3.11/site-packages (from xtcocotools>=1.12->mmpose>=1.1.0) (60.2.0)
# Collecting cython>=0.27.3 (from xtcocotools>=1.12->mmpose>=1.1.0)
#   Downloading Cython-3.0.10-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->mmpose>=1.1.0) (2.8.2)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from chumpy->mmpose>=1.1.0) (1.16.0)
# Requirement already satisfied: torch==2.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from torchvision->mmpose>=1.1.0) (2.2.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch==2.2.2->torchvision->mmpose>=1.1.0) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch==2.2.2->torchvision->mmpose>=1.1.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.2.2->torchvision->mmpose>=1.1.0) (1.3.0)
# Downloading mmpose-1.3.1-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.9 MB/s eta 0:00:00a 0:00:01
# Downloading xtcocotools-1.14.3-cp311-cp311-macosx_10_9_universal2.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 10.3 MB/s eta 0:00:00
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading torchvision-0.17.2-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.9 MB/s eta 0:00:00a 0:00:01
# Downloading Cython-3.0.10-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 14.8 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: chumpy
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58281 sha256=1ef72eea56c1d86c63c0f06e50473f8d7fe83ea61a0cc95bde7c44de6fc1e360
#   Stored in directory: /Users/renabi/Library/Caches/pip/wheels/91/96/31/3e16aa7084783b2e57a81bb9a7fa3598d32445a964b1692259
# Successfully built chumpy
# Installing collected packages: json-tricks, cython, chumpy, xtcocotools, torchvision, mmpose
# Successfully installed chumpy-0.70 cython-3.0.10 json-tricks-3.17.3 mmpose-1.3.1 torchvision-0.17.2 xtcocotools-1.14.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from mmpose.apis import inference_topdown, init_model
from mmpose.utils import register_all_modules

register_all_modules()

config_file = 'td-hm_hrnet-w48_8xb32-210e_coco-256x192.py'
checkpoint_file = 'td-hm_hrnet-w48_8xb32-210e_coco-256x192-0e67c616_20220913.pth'
model = init_model(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'

# please prepare an image with person
results = inference_topdown(model, 'demo.jpg')

# %%
from mmpose.apis import MMPoseInferencer

img_path = 'tests/data/coco/000000000785.jpg'   # replace this with your own image path

# instantiate the inferencer using the model alias
inferencer = MMPoseInferencer('human')

# The MMPoseInferencer API employs a lazy inference approach,
# creating a prediction generator when given input
result_generator = inferencer(img_path, show=True)
result = next(result_generator)

config_file = "configs/hand_2d_keypoint/topdown_regression/onehand10k/td-reg_res50_8xb64-210e_onehand10k-256x256.py",
        detector = "Hand"

# %%
import cv2
from mmpose.apis import (inference_top_down_pose_model, init_pose_model, vis_pose_result, process_mmdet_results)
from mmdet.apis import inference_detector, init_detector


pose_config = 'configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/hrnet_w48_coco_256x192.py'
pose_checkpoint = 'https://download.openmmlab.com/mmpose/top_down/hrnet/hrnet_w48_coco_256x192-b9e0b3ab_20200708.pth'

# initialize pose model
pose_model = init_pose_model(pose_config, pose_checkpoint)
# initialize detector
det_model = init_detector(det_config, det_checkpoint)

img = 'tests/data/coco/000000196141.jpg'

# inference detection
mmdet_results = inference_detector(det_model, img)

# extract person (COCO_ID=1) bounding boxes from the detection results
person_results = process_mmdet_results(mmdet_results, cat_id=1)

# inference pose
pose_results, returned_outputs = inference_top_down_pose_model(
    pose_model,
    img,
    person_results,
    bbox_thr=0.3,
    format='xyxy',
    dataset=pose_model.cfg.data.test.type)

# show pose estimation results
vis_result = vis_pose_result(
    pose_model,
    img,
    pose_results,
    dataset=pose_model.cfg.data.test.type,
    show=False)
# reduce image size
vis_result = cv2.resize(vis_result, dsize=None, fx=0.5, fy=0.5)

if local_runtime:
    from IPython.display import Image, display
    import tempfile
    import os.path as osp
    with tempfile.TemporaryDirectory() as tmpdir:
        file_name = osp.join(tmpdir, 'pose_results.png')
        cv2.imwrite(file_name, vis_result)
        display(Image(file_name))
else:
    cv2_imshow(vis_result)
